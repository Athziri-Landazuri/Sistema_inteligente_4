# %% [markdown]
# <a href="https://colab.research.google.com/github/Athziri-Landazuri/Sistema_inteligente_4/blob/main/Copia_de_Introducci%C3%B3n_a_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
s = pd.Series([3,-5,7,4], index=['a','b','c','d'])
s # s es una serie, un arreglo de números indexados
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %% [markdown]
# Podemos acceder a los elementos de la serie como lo haríamos con un diccionario

# %%
s['a']
# Out:
# 3

# %% [markdown]
# Asignaciones:

# %%
s['b'] = -7
s
# Out:
# a    3
# b   -7
# c    7
# d    4
# dtype: int64

# %% [markdown]
# soltar elemento

# %%
s.drop(['a'])
# Out:
# b   -7
# c    7
# d    4
# dtype: int64

# %% [markdown]
# # Dataframe

# %% [markdown]
# Otra estructura de pandas es el "dataframe"

# %%
data = {'Nombre' : ['Javier','Carlos','José','Fabiola'],
        'Edad' : [28,25,56,21],
        'Calificación' : [100,89,48,75]}

# %%
df = pd.DataFrame(data)
print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Nombre  Edad  Calificación
# 0   Javier    28           100
# 1   Carlos    25            89
# 2     José    56            48
# 3  Fabiola    21            75

# %%
df
# Out:
#     Nombre  Edad  Calificación
# 0   Javier    28           100
# 1   Carlos    25            89
# 2     José    56            48
# 3  Fabiola    21            75

# %%
df.iat[0,0]
# Out:
# 'Javier'

# %%
df.iat[1,2]
# Out:
# 89

# %%
print(df.at[1, 'Nombre'])
print(df.at[2, 'Calificación'])
# Out:
# Carlos
# 48

# %% [markdown]
# Asignaciones

# %%
df.at[0, 'Nombre'] = 'Enrique'
df

# %% [markdown]
# soltar elemento

# %%
df.drop('Calificación', axis = 1) # 0 -> registro   1 -> columna
# Out:
#     Nombre  Edad
# 0   Javier    28
# 1   Carlos    25
# 2     José    56
# 3  Fabiola    21

# %% [markdown]
# Esto NO modifica el dataframe, es decir, no estamos eliminando los elementos del dataframe

# %%
df
# Out:
#     Nombre  Edad  Calificación
# 0   Javier    28           100
# 1   Carlos    25            89
# 2     José    56            48
# 3  Fabiola    21            75

# %% [markdown]
# Si queremos hacer modificaciones, haríamos algo como

# %%
df2 = df.drop('Edad', axis=1)
df2
# Out:
#     Nombre  Calificación
# 0   Javier           100
# 1   Carlos            89
# 2     José            48
# 3  Fabiola            75

# %% [markdown]
# # Leer archivos

# %%
# !wget -nc "https://raw.githubusercontent.com/Jegovila/SI4/main/0%20Introducci%C3%B3n/C%C3%B3digos/Python/countries.csv"
# Out:
# File ‘countries.csv’ already there; not retrieving.

# %%
df = pd.read_csv('countries.csv')
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
df.head(10)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# 5  Afghanistan  1977  14880372.0      Asia   38.438  786.113360
# 6  Afghanistan  1982  12881816.0      Asia   39.854  978.011439
# 7  Afghanistan  1987  13867957.0      Asia   40.822  852.395945
# 8  Afghanistan  1992  16317921.0      Asia   41.674  649.341395
# 9  Afghanistan  1997  22227415.0      Asia   41.763  635.341351

# %%
df.tail()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
df.tail(10)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1694  Zimbabwe  1962   4277736.0    Africa   52.358  527.272182
# 1695  Zimbabwe  1967   4995432.0    Africa   53.995  569.795071
# 1696  Zimbabwe  1972   5861135.0    Africa   55.635  799.362176
# 1697  Zimbabwe  1977   6642107.0    Africa   57.674  685.587682
# 1698  Zimbabwe  1982   7636524.0    Africa   60.363  788.855041
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')

# %% [markdown]
# Recomendable siempre revisar los tipos de datos en las columnas con:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# Importante: tener en cuenta que si una columna debe tener números (como la columna de años) y el Dtype fuera de tipo object (NO int64 NI float64, etc), es probable que haya algún dato incorrecto (corrupto)

# %% [markdown]
# Con "describe" obtendremos las estadísticas básicas de todas las variables que sean numéricas.

# %%
df.describe()
# Out:
#              year           pop      lifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %% [markdown]
# Es posbile manejar el dataFrame como arreglo de numpy con:

# %%
df.values
# Out:
# array([['Afghanistan', 1952, 8425333.0, 'Asia', 28.801, 779.4453145],
#        ['Afghanistan', 1957, 9240934.0, 'Asia', 30.332, 820.8530296],
#        ['Afghanistan', 1962, 10267083.0, 'Asia', 31.997, 853.10071],
#        ...,
#        ['Zimbabwe', 1997, 11404948.0, 'Africa', 46.809, 792.4499603],
#        ['Zimbabwe', 2002, 11926563.0, 'Africa', 39.989, 672.0386227],
#        ['Zimbabwe', 2007, 12311143.0, 'Africa', 43.487, 469.7092981]],
#       dtype=object)

# %% [markdown]
# Será de tipo objecto a menos que solo contenga números.

# %%
df.mean()
# Out:
# <ipython-input-33-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# year         1.979500e+03
# pop          2.960121e+07
# lifeExp      5.947444e+01
# gdpPercap    7.215327e+03
# dtype: float64

# %%
df.max()
# Out:
# country          Zimbabwe
# year                 2007
# pop          1318683096.0
# continent         Oceania
# lifeExp            82.603
# gdpPercap     113523.1329
# dtype: object

# %%
df = df.rename(columns={'gdpPercap':'PIB'})
df
# Out:
#           country  year         pop continent  lifeExp         PIB
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df['country'] # esto es una serie (notar que no imprime el encabezado)
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
#o bien
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %% [markdown]
# los nombres de las columnas se vuelven atributos de esta clase, cuidar que el nombre de la columna no sea igual que una función dentro de los métodos del dataframe, por eso se recomienda usar la primera opción (df['country']).

# %% [markdown]
# Si ponemos doble corchete ya no será una serie, sino que será un dataframe

# %%
df2 = df[['country', 'PIB']]
df2
# Out:
#           country         PIB
# 0     Afghanistan  779.445314
# 1     Afghanistan  820.853030
# 2     Afghanistan  853.100710
# 3     Afghanistan  836.197138
# 4     Afghanistan  739.981106
# ...           ...         ...
# 1699     Zimbabwe  706.157306
# 1700     Zimbabwe  693.420786
# 1701     Zimbabwe  792.449960
# 1702     Zimbabwe  672.038623
# 1703     Zimbabwe  469.709298
#
# [1704 rows x 2 columns]

# %%
df.replace(1952,'one')
# Out:
#           country  year         pop continent  lifeExp         PIB
# 0     Afghanistan   one   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# De nuevo, esto no reemplaza el df

# %%
df
# Out:
#           country  year         pop continent  lifeExp         PIB
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# si queremos modificar el df será con df = df.replace(1952,'one')

# %% [markdown]
# # Filtros

# %% [markdown]
# Primero con una serie

# %%
s
# Out:
# a    3
# b   -7
# c    7
# d    4
# dtype: int64

# %%
s > 5
# Out:
# a    False
# b    False
# c     True
# d    False
# dtype: bool

# %% [markdown]
# Ahora con el dataframe. Comparamos la serie df.country, con la cadena 'Mexico'

# %%
df[df.country == 'Mexico']
# Out:
#     country  year          pop continent  lifeExp           PIB
# 984  Mexico  1952   30144317.0  Americas   50.789   3478.125529
# 985  Mexico  1957   35015548.0  Americas   55.190   4131.546641
# 986  Mexico  1962   41121485.0  Americas   58.299   4581.609385
# 987  Mexico  1967   47995559.0  Americas   60.110   5754.733883
# 988  Mexico  1972   55984294.0  Americas   62.361   6809.406690
# 989  Mexico  1977   63759976.0  Americas   65.032   7674.929108
# 990  Mexico  1982   71640904.0  Americas   67.405   9611.147541
# 991  Mexico  1987   80122492.0  Americas   69.498   8688.156003
# 992  Mexico  1992   88111030.0  Americas   71.455   9472.384295
# 993  Mexico  1997   95895146.0  Americas   73.670   9767.297530
# 994  Mexico  2002  102479927.0  Americas   74.902  10742.440530
# 995  Mexico  2007  108700891.0  Americas   76.195  11977.574960

# %%
dfmex = df[df.country == 'Mexico']
dfmex
# Out:
#     country  year          pop continent  lifeExp           PIB
# 984  Mexico  1952   30144317.0  Americas   50.789   3478.125529
# 985  Mexico  1957   35015548.0  Americas   55.190   4131.546641
# 986  Mexico  1962   41121485.0  Americas   58.299   4581.609385
# 987  Mexico  1967   47995559.0  Americas   60.110   5754.733883
# 988  Mexico  1972   55984294.0  Americas   62.361   6809.406690
# 989  Mexico  1977   63759976.0  Americas   65.032   7674.929108
# 990  Mexico  1982   71640904.0  Americas   67.405   9611.147541
# 991  Mexico  1987   80122492.0  Americas   69.498   8688.156003
# 992  Mexico  1992   88111030.0  Americas   71.455   9472.384295
# 993  Mexico  1997   95895146.0  Americas   73.670   9767.297530
# 994  Mexico  2002  102479927.0  Americas   74.902  10742.440530
# 995  Mexico  2007  108700891.0  Americas   76.195  11977.574960

# %% [markdown]
# dos filtros a la vez

# %%
df[(df.country == 'Mexico') & (df.year >= 1977)]
# Out:
#     country  year          pop continent  lifeExp           PIB
# 989  Mexico  1977   63759976.0  Americas   65.032   7674.929108
# 990  Mexico  1982   71640904.0  Americas   67.405   9611.147541
# 991  Mexico  1987   80122492.0  Americas   69.498   8688.156003
# 992  Mexico  1992   88111030.0  Americas   71.455   9472.384295
# 993  Mexico  1997   95895146.0  Americas   73.670   9767.297530
# 994  Mexico  2002  102479927.0  Americas   74.902  10742.440530
# 995  Mexico  2007  108700891.0  Americas   76.195  11977.574960

# %% [markdown]
# O bien

# %%
df[df.country == 'Mexico'][df.year >= 1977] #primero recortamos con Mexico y el resultado con >=1977
# Out:
# <ipython-input-46-20a00ec1fc86>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.country == 'Mexico'][df.year >= 1977] #primero recortamos con Mexico y el resultado con >=1977
#     country  year          pop continent  lifeExp           PIB
# 989  Mexico  1977   63759976.0  Americas   65.032   7674.929108
# 990  Mexico  1982   71640904.0  Americas   67.405   9611.147541
# 991  Mexico  1987   80122492.0  Americas   69.498   8688.156003
# 992  Mexico  1992   88111030.0  Americas   71.455   9472.384295
# 993  Mexico  1997   95895146.0  Americas   73.670   9767.297530
# 994  Mexico  2002  102479927.0  Americas   74.902  10742.440530
# 995  Mexico  2007  108700891.0  Americas   76.195  11977.574960

# %%
df2 = df[df.country == 'Mexico'][df.year >= 1977]
df2
# Out:
# <ipython-input-47-5a8416786668>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df[df.country == 'Mexico'][df.year >= 1977]
#     country  year          pop continent  lifeExp           PIB
# 989  Mexico  1977   63759976.0  Americas   65.032   7674.929108
# 990  Mexico  1982   71640904.0  Americas   67.405   9611.147541
# 991  Mexico  1987   80122492.0  Americas   69.498   8688.156003
# 992  Mexico  1992   88111030.0  Americas   71.455   9472.384295
# 993  Mexico  1997   95895146.0  Americas   73.670   9767.297530
# 994  Mexico  2002  102479927.0  Americas   74.902  10742.440530
# 995  Mexico  2007  108700891.0  Americas   76.195  11977.574960

# %%
df2 = df2.reset_index()
df2
# Out:
#    index country  year          pop continent  lifeExp           PIB
# 0    989  Mexico  1977   63759976.0  Americas   65.032   7674.929108
# 1    990  Mexico  1982   71640904.0  Americas   67.405   9611.147541
# 2    991  Mexico  1987   80122492.0  Americas   69.498   8688.156003
# 3    992  Mexico  1992   88111030.0  Americas   71.455   9472.384295
# 4    993  Mexico  1997   95895146.0  Americas   73.670   9767.297530
# 5    994  Mexico  2002  102479927.0  Americas   74.902  10742.440530
# 6    995  Mexico  2007  108700891.0  Americas   76.195  11977.574960

# %%
df2 = df2.drop('index',axis=1)
df2
# Out:
#   country  year          pop continent  lifeExp           PIB
# 0  Mexico  1977   63759976.0  Americas   65.032   7674.929108
# 1  Mexico  1982   71640904.0  Americas   67.405   9611.147541
# 2  Mexico  1987   80122492.0  Americas   69.498   8688.156003
# 3  Mexico  1992   88111030.0  Americas   71.455   9472.384295
# 4  Mexico  1997   95895146.0  Americas   73.670   9767.297530
# 5  Mexico  2002  102479927.0  Americas   74.902  10742.440530
# 6  Mexico  2007  108700891.0  Americas   76.195  11977.574960

# %%
df2.sort_values('PIB')
# Out:
#   country  year          pop continent  lifeExp           PIB
# 0  Mexico  1977   63759976.0  Americas   65.032   7674.929108
# 2  Mexico  1987   80122492.0  Americas   69.498   8688.156003
# 3  Mexico  1992   88111030.0  Americas   71.455   9472.384295
# 1  Mexico  1982   71640904.0  Americas   67.405   9611.147541
# 4  Mexico  1997   95895146.0  Americas   73.670   9767.297530
# 5  Mexico  2002  102479927.0  Americas   74.902  10742.440530
# 6  Mexico  2007  108700891.0  Americas   76.195  11977.574960

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'pop'}>],
#        [<Axes: title={'center': 'lifeExp'}>,
#         <Axes: title={'center': 'PIB'}>]], dtype=object)

# %%
df[df.country == 'Mexico'].plot(x='year', y='PIB')
# Out:
# <Axes: xlabel='year'>

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='year', ylabel='year'>,
#         <Axes: xlabel='pop', ylabel='year'>,
#         <Axes: xlabel='lifeExp', ylabel='year'>,
#         <Axes: xlabel='PIB', ylabel='year'>],
#        [<Axes: xlabel='year', ylabel='pop'>,
#         <Axes: xlabel='pop', ylabel='pop'>,
#         <Axes: xlabel='lifeExp', ylabel='pop'>,
#         <Axes: xlabel='PIB', ylabel='pop'>],
#        [<Axes: xlabel='year', ylabel='lifeExp'>,
#         <Axes: xlabel='pop', ylabel='lifeExp'>,
#         <Axes: xlabel='lifeExp', ylabel='lifeExp'>,
#         <Axes: xlabel='PIB', ylabel='lifeExp'>],
#        [<Axes: xlabel='year', ylabel='PIB'>,
#         <Axes: xlabel='pop', ylabel='PIB'>,
#         <Axes: xlabel='lifeExp', ylabel='PIB'>,
#         <Axes: xlabel='PIB', ylabel='PIB'>]], dtype=object)

# %% [markdown]
# Notar que graficar una variable consigo misma no tendría sentido (nos daría una línea) y por eso mejor nos despliega el histograma

# %%
pd.plotting.scatter_matrix(df[df.country=='Mexico'])

# %% [markdown]
# # Práctica

# %% [markdown]
# 1. ¿Cuántos y cuales países tienen una esperanza de vida mayor o igual a 80 en el 2002?

# %%
dfv80 = df[(df.lifeExp >= 80) & (df.year == 2002)]
dfv80.country
# Out:
# 70            Australia
# 670     Hong Kong China
# 694             Iceland
# 778               Italy
# 802               Japan
# 1474             Sweden
# 1486        Switzerland
# Name: country, dtype: object

# %%
len(dfv80.country)
# Out:
# 7

# %% [markdown]
# 2. ¿Pais con el mayor Producto Interno Bruto?

# %%
pibmax = df.PIB.max()
df[df.PIB == pibmax]
# Out:
#     country  year       pop continent  lifeExp          PIB
# 853  Kuwait  1957  212846.0      Asia   58.033  113523.1329

# %% [markdown]
# 3. ¿En qué año México sobrepaso los 70 millones de habitantes?

# %%
df3 = df[df['country'] == 'Mexico']
df3 = df3[df3['pop'] >= 70000000.0]
df3
# Out:
#     country  year          pop continent  lifeExp           PIB
# 990  Mexico  1982   71640904.0  Americas   67.405   9611.147541
# 991  Mexico  1987   80122492.0  Americas   69.498   8688.156003
# 992  Mexico  1992   88111030.0  Americas   71.455   9472.384295
# 993  Mexico  1997   95895146.0  Americas   73.670   9767.297530
# 994  Mexico  2002  102479927.0  Americas   74.902  10742.440530
# 995  Mexico  2007  108700891.0  Americas   76.195  11977.574960

# %%
df3["year"].iloc[0]
# Out:
# 1982
